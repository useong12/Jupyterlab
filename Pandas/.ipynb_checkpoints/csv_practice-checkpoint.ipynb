# %%
import pandas as pd
import os
print(os.getcwd())
# Out:
# C:\Users\ws060\Pandas

# %%
file_name = "./서울특별시_공원 내 운동기구 설치 현황_20201231.csv"

# %%
df = pd.read_csv(file_name,encoding="cp949")
df
# Out:
#              구분      위치(구역명)    운동기구 기종명   운동기구 수량                  관리번호  \
# 0      남산공원(회현)    안중근 기념관 옆       스텝사이클          1   남삼회현-1(안중근기념관옆)-1
# 1      남산공원(회현)    안중근 기념관 옆     크로스 컨트리          1   남삼회현-1(안중근기념관옆)-2
# 2      남산공원(회현)    안중근 기념관 옆      체어 웨이트          1   남삼회현-1(안중근기념관옆)-3
# 3      남산공원(회현)    안중근 기념관 옆      롤링웨이스트          1   남삼회현-1(안중근기념관옆)-4
# 4      남산공원(회현)    안중근 기념관 옆        폴웨이트          1   남삼회현-1(안중근기념관옆)-5
# ...          ...          ...         ...       ...                  ...
# 1922      서울대공원       기린나라 앞      어깨근육풀기          1     서울대공원-2(기린나라)-2
# 1923      서울대공원       기린나라 앞       허리돌리기          1     서울대공원-2(기린나라)-3
# 1924      서울대공원       기린나라 앞      윗몸일으키기          1     서울대공원-2(기린나라)-4
# 1925      서울대공원       기린나라 앞    하이풀리운동기구          1     서울대공원-2(기린나라)-5
# 1926      서울대공원       기린나라 앞     등허리지압운동          1     서울대공원-2(기린나라)-6
#
#             관리기관
# 0      중부공원녹지사업소
# 1      중부공원녹지사업소
# 2      중부공원녹지사업소
# 3      중부공원녹지사업소
# 4      중부공원녹지사업소
# ...           ...
# 1922       서울대공원
# 1923       서울대공원
# 1924       서울대공원
# 1925       서울대공원
# 1926       서울대공원
#
# [1927 rows x 6 columns]

# %%
#print(df.dtypes)
df.columns = df.columns.str.strip()
df["구분"] = df["구분"].str.strip()
result = df.groupby("구분")["운동기구 수량"].sum()
result

with open("./park_counting.txt","w",encoding="utf-8") as file:
    file.write("공원 별 총 운동기구 설치수\n")
    file.write(result.to_string())

# %%
'''
with open("공원별 운동기구 수량.txt", "w", encoding="utf-8", newline="") as f:
        result = str(result)
        line = "\t".join(result)  
        f.write(line + "\n")
'''
# Out:
# '\nwith open("공원별 운동기구 수량.txt", "w", encoding="utf-8", newline="") as f:\n        result = str(result)\n        line = "\t".join(result)  \n        f.write(line + "\n")\n'

# %%
result = df[df["구분"]=="시민의숲공원"]
result
# Out:
#          구분  위치(구역명)    운동기구 기종명  운동기구 수량                  관리번호         관리기관
# 590  시민의숲공원     놀이터         달리기         1      시민의숲공원-1(놀이터)-1    동부공원녹지사업소
# 615  시민의숲공원   맨발지압장      윗몸일으키기         1   시민의숲공원-3(맨발지압장)-10    동부공원녹지사업소
# 616  시민의숲공원   맨발지압장     거꾸로매달리기         1   시민의숲공원-3(맨발지압장)-11    동부공원녹지사업소
# 617  시민의숲공원   맨발지압장        파도타기         1   시민의숲공원-3(맨발지압장)-12    동부공원녹지사업소

# %%
df["관리기관"] = df["관리기관"].str.strip()
result = df.groupby('관리기관')['운동기구 수량'].sum()
result.sort_values(ascending=False)
# Out:
# 관리기관
# 한강사업본부       1006
# 중부공원녹지사업소     496
# 동부공원녹지사업소     311
# 서부공원녹지사업소     120
# 서울대공원          22
# 체육시설관리사업소      18
# Name: 운동기구 수량, dtype: int64

# %%
result = df[df["운동기구 기종명"]=="달리기"]
result
# Out:
#           구분      위치(구역명) 운동기구 기종명  운동기구 수량                       관리번호  \
# 499    보라매공원          북동산      달리기        1            보라매공원-1(북동산)-4
# 590   시민의숲공원         놀이터       달리기        1           시민의숲공원-1(놀이터)-1
# 607   시민의숲공원       맨발지압장       달리기        1         시민의숲공원-3(맨발지압장)-2
# 692     천호공원        산책로3       달리기        1             천호공원-3(산책로)-8
# 694     천호공원        산책로4       달리기        1             천호공원-4(산책로)-2
# 720     율현공원   소나무산책로(1)       달리기        1   율현공원(하늘공원)-2(소나무산책로1)-1
# 726     율현공원     수변프라자입구       달리기        1   율현공원(하늘공원)-3(수변프라자입구)-3
# 733     율현공원      어린이놀이터       달리기        1    율현공원(하늘공원)-5(어린이놀이터)-1
# 741     율현공원      게이트볼장옆       달리기        1     율현공원(둥지공원)-6(게이트볼장)-4
# 809  서서울호수공원      다목적운동장       달리기        1       서서울호수공원-2(다목적운동장)-9
# 829  서서울호수공원         약수터       달리기        1          서서울호수공원-1(약수터)-3
# 854    여의도공원   1번 출입구 주변       달리기        1      여의도공원-1(1번 출입구 주변)-2
# 865    여의도공원   8번 출입구 주변       달리기        1      여의도공원-2(8번 출입구 주변)-4
# 879    여의도공원    한국전통의숲 내       달리기        1       여의도공원-3(한국전통의숲 내)-8
#
#           관리기관
# 499  동부공원녹지사업소
# 590  동부공원녹지사업소
# 607  동부공원녹지사업소
# 692  동부공원녹지사업소
# 694  동부공원녹지사업소
# 720  동부공원녹지사업소
# 726  동부공원녹지사업소
# 733  동부공원녹지사업소
# 741  동부공원녹지사업소
# 809  서부공원녹지사업소
# 829  서부공원녹지사업소
# 854  서부공원녹지사업소
# 865  서부공원녹지사업소
# 879  서부공원녹지사업소
