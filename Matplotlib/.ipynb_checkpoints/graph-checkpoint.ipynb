# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager
import numpy as np
#한글 폰트 설정
#font_list = font_manager.findSystemFonts(fontpaths=None,fontext="ttf")
#print(font_list)

path = 'C:\\Windows\\Fonts\\HYKANM.TTF'
font = font_manager.FontProperties(fname=path).get_name()
plt.rc('font',family=font)

# %%
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
sales_2019 = [100,120,140,110,130,150,160,170,180,200,190,210]
sales_2020 = [90,110,130,120,140,160,170,160,150,180,200,190]

# %%
plt.plot(months,sales_2019,label='2019')
plt.plot(months,sales_2020,label='2020')
plt.title('Monthly Sales Comparison(2019-2020)')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()

# %%
categories = ['Category 1','Category 2','Category 3','Category 4','Category 5']
data = [20,35,15,27,45]

plt.bar(categories,data)
plt.grid()
plt.ylim([0,50])
plt.title("Bar char")
plt.xlabel("Categories")
plt.ylabel("Value")

plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Category 1'),
#   Text(1, 0, 'Category 2'),
#   Text(2, 0, 'Category 3'),
#   Text(3, 0, 'Category 4'),
#   Text(4, 0, 'Category 5')])

# %%
labels = ['Grape','Melon','Banana','Apple']
sizes = [18,16,32,34]
color = ['purple','g','yellow','r']
explode = [0.1,0,0.1,0]

plt.pie(sizes,labels=labels,autopct="%1.1f%%",wedgeprops={"edgecolor":"black","width":0.7,"linewidth":1},counterclock=False,colors=color,explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x224f77d1cd0>,
#   <matplotlib.patches.Wedge at 0x224fa98ef60>,
#   <matplotlib.patches.Wedge at 0x224fa9d5190>,
#   <matplotlib.patches.Wedge at 0x224fa9d5760>],
#  [Text(1.0131934774890363, -0.6429922061531336, 'Grape'),
#   Text(-0.06906951669222933, -1.0978294047181931, 'Melon'),
#   Text(-1.1999999999999955, 1.049073360044697e-07, 'Banana'),
#   Text(0.5299292503463836, 0.9639372332404844, 'Apple')],
#  [Text(0.5910295285352711, -0.37507878692266117, '18.0%'),
#   Text(-0.03767428183212509, -0.5988160389371961, '16.0%'),
#   Text(-0.6999999999999974, 6.119594600260732e-08, '32.0%'),
#   Text(0.2890523183707546, 0.5257839454039005, '34.0%')])
